# %%
from vision.ssd.vgg_ssd import create_vgg_ssd, create_vgg_ssd_predictor
from vision.ssd.mobilenetv1_ssd import create_mobilenetv1_ssd, create_mobilenetv1_ssd_predictor
from vision.ssd.mobilenetv1_ssd_lite import create_mobilenetv1_ssd_lite, create_mobilenetv1_ssd_lite_predictor
from vision.ssd.squeezenet_ssd_lite import create_squeezenet_ssd_lite, create_squeezenet_ssd_lite_predictor
from vision.ssd.mobilenet_v2_ssd_lite import create_mobilenetv2_ssd_lite, create_mobilenetv2_ssd_lite_predictor
from vision.utils.misc import Timer
from mss import mss
import cv2
import numpy as np
from PIL import ImageGrab
import time
import pyautogui
from numpy import ones,vstack
from numpy.linalg import lstsq
from statistics import mean
from directkeys import PressKey, ReleaseKey, W, A, S, D
import pyautogui

# %%
## Not to detect : 
## aeroplane
## bird
## boat
## cat
## chair
## diningtable
## pottedplant
## sheep
## sofa
## tvmonitor
## bottle
## motorbike

no_need = ['aeroplane', 'bird', 'boat', 'cat', 'chair', 'diningtable', 'pottedplant', 'sheep', 'sofa', 'tvmonitor', 'bottle', 'motorbike']

# %%
# utility functions
def straight():
    PressKey(W)
    ReleaseKey(A)
    ReleaseKey(D)
    print('straight')

def left():
    PressKey(A)
    #ReleaseKey(W)#
    ReleaseKey(D)
    #ReleaseKey(A)   # Basically tapping the key 'A' once
    #ReleaseKey(W)
    print('left')

def right():
    PressKey(D)
    #ReleaseKey(W)#
    ReleaseKey(A)
    #ReleaseKey(D)   # Basically tapping the key 'A' once
    #ReleaseKey(W)
    print('right')

def stop():
    ReleaseKey(W)
    ReleaseKey(A)
    ReleaseKey(D)

def reposition(count):
    if count == 0:
        straight()
    while(count != 0):
        print(count)
        if count > 0:
            for i in range(3):
                straight()
            left()
            count -= 1
        elif count < 0:
            for i in range(3):
                straight()
            right()
            count += 1

# %%
net_type = r'mb1-ssd'
model_path = r'models/mobilenet-v1-ssd-mp-0_675.pth'
label_path = r'models/voc-model-labels.txt'

class_names = [name.strip() for name in open(label_path).readlines()]
num_classes = len(class_names)

net = create_mobilenetv1_ssd(len(class_names), is_test=True)
net.load(model_path)
predictor = create_mobilenetv1_ssd_predictor(net, candidate_size=200)

# %%
timer = Timer()

monitor = {'top' : 40, 'left' : 0, 'width' : 800, 'height' : 600}
sct = mss()

count = 0

# delay
for i in range(4):
    print(4 - i)
    time.sleep(1)
# kick
for i in range(10):
    time.sleep(0.3)
    straight()

while True:
    sct_image = sct.grab(monitor)
    orig_image = np.array(sct_image)
    if orig_image is None:
        continue

    image = cv2.cvtColor(orig_image, cv2.COLOR_BGR2RGB)
    timer.start()
    boxes, labels, probs = predictor.predict(image, 10, 0.4)
    #print("boxes : ", boxes)
    #print("labels : ", labels)
    #print("Probs : ", probs)
    interval = timer.end()
    #print('Time: {:.2f}s, Detect Objects: {:d}.'.format(interval, labels.size(0)))

    ## Game specific : Finding max probability of person, that'll be Jacob
    persons = []
    jacob = ['jacob', -1, [-1, -1, -1, -1]]   # characteristics of jacob
    for i in range(boxes.size(0)):
        box = boxes[i, :]
        label = class_names[labels[i]]
        if str(label) == 'person':
            persons.append(float(probs[i]))
    #print('persons : ', persons)
    if(len(persons) != 0):
        jacob[1] = max(persons)     # person with highest probability will be jacob
        jacob[2] = [box[0], box[1], box[2], box[3]]
    #print('Jacob' , jacob)
    ##

    for i in range(boxes.size(0)):
        box = boxes[i, :]
        label = f"{class_names[labels[i]]}: {probs[i]:.2f}"
        if float(probs[i]) == jacob[1]:
            label = f"{jacob[0]}: {probs[i]:.2f}"
        label1 = label.split(':')[0]

        ## Game specific : overlapping obstacles with jacob
        if label1 not in no_need:
            cv2.rectangle(orig_image, (box[0], box[1]), (box[2], box[3]), (255, 255, 0), 4)

            cv2.putText(orig_image, label,
                        (box[0]+20, box[1]+40),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        1,  # font scale
                        (255, 0, 255),
                        2)  # line type

            if str(label1) != 'jacob':
                if label1 == 'bicycle':     # cz in dark conditions jacob belt is detected as bicycle
                    if box[0] > (jacob[2][0] - 20) and box[0] < (jacob[2][0] + 20):
                        pass
                    elif box[2] > (jacob[2][2] - 20) and box[2] < (jacob[2][2] + 20):
                        pass
                elif (box[2] > (jacob[2][0])) and (box[2] < (jacob[2][2])):
                    right()
                    count += 1
                elif (box[0] > (jacob[2][0])) and (box[0] < (jacob[2][2])):
                    left()
                    count -= 1
                else:
                    #straight()
                    #print('straight')
                    # doesn't work in busy env cz while this executes, jacob collides with other objects
                    
                    reposition(count)
                    count = 0
         
        ##
        '''
        cv2.rectangle(orig_image, (box[0], box[1]), (box[2], box[3]), (255, 2ww55, 0), 4)

        cv2.putText(orig_image, label,
                    (box[0]+20, box[1]+40),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,  # font scale
                    (255, 0, 255),
                    2)  # line type
        '''
    cv2.imshow('annotated', orig_image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# nce time:  0.03741097450256348
# straight
# Inference time:  0.033002614974975586
# straight
# Inference time:  0.028009891510009766
# straight
# straight
# Inference time:  0.02303481101989746
# right
# 1
# straight
# straight
# straight
# left
# straight
# Inference time:  0.04500842094421387
# straight
# Inference time: 0.030913591384887695
# straight
# straight
# Inference time:  0.03390932083129883
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.03246879577636719
# straight
# Inference time:  0.03999042510986328
# straight
# Inference time: 0.041994333267211914
# straight
# Inference time:  0.0339052677154541
# straight
# Inference time: 0.030848979949951172
# straight
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04018044471740723
# straight
# straight
# Inference time:  0.03597712516784668
# straight
# straight
# Inference time:  0.038942813873291016
# straight
# Inference time: 0.029921770095825195
# straight
# straight
# Inference time:  0.03490710258483887
# straight
# straight
# Inference time:  0.02900409698486328
# straight
# Inference time:  0.03206157684326172
# straight
# Inference time:  0.02892279624938965
# left
# left
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03297090530395508
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03589606285095215
# straight
# Inference time: 0.03391003608703613
# left
# -1
# straight
# straight
# straight
# right
# straight
# Inference time:  0.035902976989746094
# straight
# left
# Inference time: 0.03536558151245117
# -1
# straight
# straight
# straight
# right
# Inference time:  0.0471651554107666
# left
# Inference time: 0.0329127311706543
# left
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03490805625915527
# left
# left
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04486966133117676
# left
# right
# straight
# Inference time:  0.044879913330078125
# left
# -1
# straight
# straight
# straight
# right
# right
# right
# 2
# straight
# straight
# straight
# left
# 1
# straight
# straight
# straight
# left
# Inference time:  0.032909393310546875
# straight
# left
# left
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04687047004699707
# straight
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03091716766357422
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.037899017333984375
# straight
# left
# left
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03390860557556152
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04488372802734375
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03191685676574707
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04288768768310547
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04189443588256836
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.046875953674316406
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03390836715698242
# straight
# straight
# Inference time:  0.035903215408325195
# straight
# straight
# Inference time: 0.034908294677734375
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.033557891845703125
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.031592607498168945
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03401017189025879
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.040041208267211914
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.039125680923461914
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.030918121337890625
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03412985801696777
# left
# Inference time:  0.04413032531738281
# left
# Inference time:  0.034102678298950195
# left
# -3
# straight
# straight
# straight
# right
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.0359034538269043
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04287886619567871
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03490853309631348
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.042894601821899414
# left
# Inference time: 0.034906625747680664
# left
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04288959503173828
# straight
# Inference time:  0.0329132080078125
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04389524459838867
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.02792668342590332
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03390932083129883
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03290987014770508
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.0279233455657959
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04288291931152344
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03789925575256348
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03391122817993164
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.038895606994628906
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04288625717163086
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03391075134277344
# straight
# straight
# Inference time: 0.03690910339355469
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.045886993408203125
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03690028190612793
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.042887210845947266
# straight
# straight
# Inference time: 0.03091740608215332
# straight
# straight
# Inference time:  0.03265380859375
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.0279238224029541
# straight
# Inference time:  0.029920578002929688
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.032911062240600586
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03482413291931152
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.03198981285095215
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03391075134277344
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.035930633544921875
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04010796546936035
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.03198647499084473
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04189801216125488
# straight
# straight
# Inference time: 0.03690314292907715
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.032918453216552734
# straight
# straight
# Inference time:  0.04388904571533203
# straight
# Inference time:  0.03091740608215332
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.0320587158203125
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.029917478561401367
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.02680206298828125
# straight
# Inference time:  0.029921293258666992
# straight
# Inference time: 0.03490424156188965
# straight
# straight
# Inference time:  0.030917882919311523
# left
# left
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time: 0.033905744552612305
# straight
# straight
# straight
# Inference time:  0.04089641571044922
# straight
# straight
# Inference time: 0.0359041690826416
# straight
# straight
# Inference time:  0.033908843994140625
# straight
# straight
# Inference time: 0.03390979766845703
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03191661834716797
# straight
# straight
# Inference time:  0.03390932083129883
# straight
# straight
# Inference time:  0.03291463851928711
# straight
# straight
# Inference time: 0.029920578002929688
# straight
# straight
# Inference time:  0.03290987014770508
# straight
# Inference time:  0.03092169761657715
# straight
# Inference time:  0.032909393310546875
# left
# right
# straight
# Inference time:  0.03690147399902344
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03390979766845703
# right
# 1
# straight
# straight
# straight
# left
# Inference time: 0.03191494941711426
# straight
# Inference time:  0.030917882919311523
# straight
# straight
# Inference time:  0.03390693664550781
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03490424156188965
# straight
# Inference time: 0.03191852569580078
# straight
# left
# Inference time:  0.03889131546020508
# -1
# straight
# straight
# straight
# right
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.03590250015258789
# straight
# Inference time:  0.034906864166259766
# straight
# Inference time: 0.03291058540344238
# straight
# Inference time:  0.03490710258483887
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.031916141510009766
# straight
# straight
# Inference time:  0.04188060760498047
# straight
# Inference time: 0.030916213989257812
# straight
# straight
# Inference time:  0.03390622138977051
# straight
# Inference time:  0.0329127311706543
# straight
# Inference time:  0.0379030704498291
# straight
# Inference time: 0.03789710998535156
# straight
# straight
# Inference time:  0.048868656158447266
# straight
# straight
# Inference time:  0.04307436943054199
# straight
# Inference time:  0.0351104736328125
# straight
# Inference time: 0.034908294677734375
# straight
# Inference time:  0.03490447998046875
# straight
# straight
# Inference time: 0.03490781784057617
# straight
# straight
# Inference time:  0.03291058540344238
# straight
# Inference time:  0.054863691329956055
# straight
# Inference time:  0.025930166244506836
# straight
# Inference time:  0.024933576583862305
# straight
# Inference time:  0.028913497924804688
# straight
# straight
# Inference time:  0.039894819259643555
# straight
# straight
# Inference time: 0.03490591049194336
# straight
# Inference time:  0.03603529930114746
# straight
# Inference time: 0.036911964416503906
# straight
# Inference time:  0.035904645919799805
# straight
# straight
# Inference time:0.036905527114868164
# straight
# straight
# Inference time:  0.03700518608093262
# straight
# Inference time: 0.0359041690826416
# straight
# Inference time:  0.0418543815612793
# straight
# straight
# Inference time:  0.03989672660827637
# straight
# straight
# Inference time:  0.039159297943115234
# straight
# straight
# Inference time: 0.03391242027282715
# straight
# straight
# Inference time:  0.03291511535644531
# straight
# straight
# Inference time:  0.0438845157623291
# straight
# straight
# Inference time:  0.032434701919555664
# straight
# straight
# Inference time:  0.02891993522644043
# straight
# Inference time:  0.02892136573791504
# left
# Inference time:  0.031926631927490234
# Inference time:  0.04188990592956543
# Inference time:  0.03885149955749512
# Inference time:  0.04071474075317383
# left
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04089069366455078
# Inference time: 0.033908843994140625
# Inference time:  0.034905195236206055
# Inference time:  0.03703141212463379
# straight
# Inference time:  0.04288482666015625
# Inference time:  0.03689908981323242
# straight
# left
# Inference time: 0.03191518783569336
# left
# left
# Inference time:  0.030916213989257812
# -3
# straight
# straight
# straight
# right
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# straight
# Inference time:  0.03590703010559082
# straight
# straight
# Inference time:  0.03690195083618164
# left
# -1
# straight
# straight
# straight
# right
# Inference time: 0.04188847541809082
# straight
# straight
# Inference time:  0.033597707748413086
# right
# left
# Inference time: 0.03091740608215332
# right
# left
# Inference time:  0.039894819259643555
# right
# Inference time:  0.039357662200927734
# 1
# straight
# straight
# straight
# left
# Inference time:  0.036004066467285156
# straight
# Inference time: 0.03601837158203125
# straight
# Inference time:  0.03701019287109375
# left
# left
# left
# -3
# straight
# straight
# straight
# right
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03728818893432617
# left
# left
# right
# -1
# straight
# straight
# straight
# right
# Inference time:  0.04107999801635742
# straight
# Inference time:  0.032996177673339844
# left
# Inference time:  0.03302574157714844
# left
# Inference time: 0.03502941131591797
# left
# Inference time:  0.0330049991607666
# left
# Inference time:  0.030981779098510742
# left
# Inference time:  0.02301478385925293
# -5
# straight
# straight
# straight
# right
# -4
# straight
# straight
# straight
# right
# -3
# straight
# straight
# straight
# right
# -2
# straight
# straight
# straight
# right
# -1
# straight
# straight
# straight
# right
# straight
# Inference time:  0.03390955924987793
# left
# -1
# straight
# straight
# straight
# right
# Inference time:  0.03690075874328613
# straight
# Inference time:  0.05185961723327637
# straight
# Inference time:  0.03291177749633789
# straight
# Inference time:  0.04089212417602539
# straight
# Inference time: 0.03490710258483887
# straight
# Inference time:  0.03698229789733887
# straight
# straight
# Inference time: 0.033425092697143555
# straight
# straight
# Inference time:  0.03988504409790039
# straight
# straight
# Inference time: 0.041887521743774414
# straight
# Inference time:  0.03390645980834961
# straight
# Inference time: 0.03490781784057617
# straight
# straight
# Inference time:  0.0249326229095459
# straight
# straight
# Inference time: 0.03091597557067871
# straight
# straight
# Inference time:  0.02892160415649414
# straight
# Inference time: 0.042025089263916016
# straight
# Inference time:  0.03198957443237305
# straight
# Inference time: 0.034905433654785156
# Inference time:  0.03600001335144043
# straight
# Inference time: 0.04309868812561035
# straight
# Inference time:  0.035947561264038086
# straight
# Inference time: 0.0369718074798584
# straight
# Inference time:  0.0388948917388916
# right
# 1
# straight
# straight
# straight
# left
# Inference time: 0.03790616989135742
# Inference time:  0.03745555877685547
# Inference time: 0.03597092628479004
# Inference time:  0.030898094177246094
# Inference time:  0.028922557830810547
# Inference time:  0.029921531677246094
# Inference time:  0.043883562088012695
# straight
# Inference time:0.034905433654785156
# straight
# Inference time:  0.034908294677734375
# Inference time:  0.0359036922454834
# Inference time:  0.03589963912963867
# Inference time:  0.04095029830932617
# Inference time:  0.03496098518371582
# Inference time:  0.03993630409240723
# Inference time:  0.04388308525085449
# Inference time:  0.03996992111206055
# Inference time:  0.034036874771118164
# Inference time:  0.0404047966003418
# Inference time:  0.037900686264038086
# Inference time:  0.03663802146911621
# Inference time:  0.03191637992858887
# Inference time:  0.03291153907775879
# Inference time:  0.03790616989135742
# Inference time:  0.03198122978210449
# Inference time:  0.02692270278930664
# Inference time:  0.03291034698486328
# Inference time:  0.030916929244995117
# Inference time:  0.0418858528137207
# Inference time:  0.04288458824157715
# Inference time:  0.03989076614379883
# Inference time:  0.038896799087524414
# Inference time: 0.03889608383178711
# Inference time:  0.03191351890563965
# Inference time: 0.038893938064575195
# Inference time:  0.03690600395202637
# Inference time:  0.03889060020446777
# Inference time:  0.030916929244995117
# Inference time:  0.04089045524597168
# Inference time:  0.03795480728149414
# Inference time:  0.028923988342285156
# Inference time:  0.04288458824157715
# Inference time: 0.02891826629638672
# Inference time:  0.038893938064575195
# Inference time:  0.03490424156188965
# Inference time:  0.028923749923706055
# Inference time:  0.0390477180480957
# Inference time:  0.04013180732727051
# Inference time:  0.041043758392333984
# Inference time:  0.03909468650817871
# Inference time:  0.03303670883178711
# Inference time:  0.044919490814208984
# Inference time:  0.04306364059448242
# Inference time:  0.04306626319885254
# Inference time: 0.031062602996826172
# Inference time:  0.0319671630859375
# Inference time: 0.042995452880859375
# Inference time:  0.033052921295166016
# Inference time:  0.028985023498535156
# Inference time:  0.03196096420288086
# Inference time:  0.04341244697570801
# Inference time:  0.030912160873413086
# Inference time:  0.03091573715209961
# Inference time:  0.030015945434570312
# Inference time:  0.03594207763671875
# Inference time:  0.047983646392822266
# Inference time: 0.03789377212524414
# Inference time:  0.03398585319519043
# Inference time: 0.04089188575744629
# Inference time:  0.03701353073120117
# Inference time:  0.03390192985534668
# Inference time:  0.03290867805480957
# Inference time:  0.034924983978271484
# Inference time: 0.03677988052368164
# Inference time:  0.03690218925476074
# Inference time:  0.02796649932861328
# Inference time:  0.029918909072875977
# Inference time:  0.044953107833862305
# Inference time:  0.03195691108703613
# Inference time:  0.03500962257385254
# Inference time:  0.0420072078704834
# Inference time:  0.030968666076660156
# Inference time:  0.03398728370666504
# Inference time:  0.048922061920166016
# Inference time: 0.03386878967285156
# Inference time:  0.04197263717651367
# Inference time: 0.03790616989135742
# Inference time:  0.03490138053894043
# Inference time:  0.03197813034057617
# Inference time:  0.034034013748168945
# Inference time:  0.04487442970275879
# Inference time:  0.0430600643157959
# Inference time:  0.033876895904541016
# Inference time: 0.036899566650390625
# right
# Inference time:  0.025931358337402344
# right
# Inference time:  0.03358721733093262
# Inference time:  0.025933265686035156
# Inference time:  0.040166378021240234
# Inference time:  0.03390836715698242
# Inference time:  0.032918453216552734
# Inference time:  0.0489954948425293
# 2
# straight
# straight
# straight
# left
# 1
# straight
# straight
# straight
# left
# Inference time: 0.03191566467285156
# Inference time:  0.04089212417602539
# straight
# Inference time: 0.039893388748168945
# Inference time:  0.031914472579956055
# Inference time:  0.038893699645996094
# Inference time:  0.034906625747680664
# Inference time:  0.04687237739562988
# Inference time:  0.035794734954833984
# Inference time:  0.030949115753173828
# Inference time:  0.034944772720336914
# Inference time:  0.03191709518432617
# Inference time:  0.030163049697875977
# Inference time:  0.029176712036132812
# Inference time:  0.03091740608215332
# Inference time:  0.02904200553894043
# Inference time:  0.03608441352844238
# Inference time: 0.03596377372741699
# Inference time:  0.03095865249633789
# Inference time:  0.0339045524597168
# Inference time:  0.03590130805969238
# straight
# Inference time:  0.03889155387878418
# Inference time: 0.030986309051513672
# Inference time:  0.04090166091918945
# Inference time:  0.035953521728515625
# Inference time:  0.03699684143066406
# Inference time:  0.03498077392578125
# Inference time: 0.031021595001220703
# straight
# Inference time:  0.04807877540588379
# right
# 1
# straight
# straight
# straight
# left
# Inference time:  0.032912492752075195
# Inference time:  0.024932146072387695
# straight
# Inference time:  0.03192329406738281
# Inference time:  0.0299227237701416
# Inference time:  0.04288220405578613
# Inference time: 0.03396964073181152
# straight
# Inference time:  0.03848838806152344
# Inference time:  0.03689932823181152
# Inference time:  0.03290748596191406
# Inference time:  0.04192924499511719
# Inference time:  0.038036346435546875
# Inference time:  0.03595280647277832
# Inference time:  0.04558134078979492
# Inference time: 0.04105710983276367
# Inference time:  0.035187482833862305
# Inference time:  0.027925968170166016
# Inference time:  0.03390932083129883
# straight
# Inference time:  0.04088234901428223
# straight
# Inference time:  0.0299224853515625
# Inference time:  0.02892446517944336
# Inference time:  0.046011924743652344
# Inference time: 0.04136967658996582
# right
# 1
# straight
# straight
# straight
# left
# Inference time:  0.033911943435668945
# left
# right
# straight
# Inference time: 0.03491568565368652
# Inference time:  0.03490400314331055
# straight
# Inference time:  0.029920578002929688
# Inference time:  0.026930570602416992
# Inference time:  0.03390765190124512
# Inference time: 0.03490614891052246
# Inference time:  0.04089045524597168
# Inference time:  0.035901784896850586
# Inference time:  0.03091597557067871
# straight
# Inference time:  0.020941972732543945
# Inference time:  0.029920578002929688
# Inference time:  0.02892279624938965
# Inference time:  0.03490757942199707
# Inference time: 0.0379023551940918
# Inference time:  0.02443861961364746
# Inference time:  0.03589010238647461
# Inference time:  0.020943403244018555
# Inference time:  0.022938013076782227
# Inference time:  0.022938251495361328
# Inference time:  0.02293539047241211
# Inference time:  0.030427217483520508
# Inference time:  0.026915788650512695
# Inference time:  0.022937774658203125
# Inference time:  0.025928974151611328
# Inference time:  0.020942211151123047
