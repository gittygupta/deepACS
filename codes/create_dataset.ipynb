# %%
import numpy as np
import cv2
import time
from getkeys import key_check
import os
from mss import mss

START_TIME = time.time()

def keys_to_output(keys):
    # [A, W, D] <- only these key combos gonna be there
    output = [0 ,0, 0]  # not doing anything
                        # when any is 1, we do that command
    if 'A' in keys:
        output[0] = 1
    elif 'D' in keys:
        output[2] = 1
    elif 'W' in keys:
        output[1] = 1
    return output

for i in list(range(0, 4))[::-1]:
    print(i + 1)
    time.sleep(1)



monitor = {'top' : 40, 'left' : 0, 'width' : 800, 'height' : 600}
sct = mss()
last_time = time.time()

# We will keep appending training data
filename = 'training_data1.npy'      # numpy file
training_data = []
if os.path.isfile(filename):
    print('File exists, loading Previous data!')
    training_data = list(np.load(filename, allow_pickle = True))
else:
    print('File does not exist, starting fresh')

# in this main loop we do precessing
while(True):
    sct_image = sct.grab(monitor)
    screen = np.array(sct_image)
    screen = cv2.cvtColor(screen, cv2.COLOR_BGR2GRAY)   # We want the NN to play irrespective of colors
    screen = cv2.resize(screen, (80, 60))
    keys = key_check()
    output = keys_to_output(keys)
    training_data.append([screen, output])
    print("Capture FPS = " + str(int(1/(time.time() - last_time))))
    last_time = time.time()

    if len(training_data) % 500 == 0:
        print('Dataset size : ' + str(len(training_data)))
        np.save(filename, training_data[:-150])
    if (time.time() - START_TIME) >= 300:
        break
# Out:
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 27
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 38
# Capture FPS = 50
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 26
# Capture FPS = 37
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 34
# Capture FPS = 45
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 52
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 58
# Capture FPS = 34
# Capture FPS = 27
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 37
# Capture FPS = 27
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 27
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 27
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 26
# Capture FPS = 37
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 37
# Capture FPS = 28
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 29
# Capture FPS = 37
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 38
# Capture FPS = 50
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 28
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 27
# Capture FPS = 39
# Capture FPS = 30
# Capture FPS = 27
# Capture FPS = 37
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 58
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 27
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 27
# Capture FPS = 34
# Capture FPS = 35
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 58
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 27
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 27
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 28
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 27
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 27
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 37
# Capture FPS = 29
# Capture FPS = 31
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 36
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 27
# Capture FPS = 30
# Capture FPS = 38
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 52
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 26
# Capture FPS = 37
# Capture FPS = 26
# Capture FPS = 40
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 37
# Capture FPS = 29
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 37
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 29
# Capture FPS = 37
# Capture FPS = 27
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 52
# Capture FPS = 34
# Capture FPS = 58
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 35
# Capture FPS = 26
# Capture FPS = 40
# Capture FPS = 30
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 28
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 52
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 37
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 28
# Capture FPS = 38
# Capture FPS = 33
# Capture FPS = 58
# Capture FPS = 31
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 27
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 35
# Capture FPS = 55
# Capture FPS = 31
# Dataset size : 116000
# Capture FPS = 0
# Capture FPS = 43
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 28
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 35
# Capture FPS = 28
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 30
# Capture FPS = 37
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 40
# Capture FPS = 50
# Capture FPS = 33
# Capture FPS = 27
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 37
# Capture FPS = 55
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 38
# Capture FPS = 27
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 37
# Capture FPS = 62
# Capture FPS = 58
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 26
# Capture FPS = 40
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 58
# Capture FPS = 31
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 33
# Capture FPS = 37
# Capture FPS = 52
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 27
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 35
# Capture FPS = 77
# Capture FPS = 55
# Capture FPS = 58
# Capture FPS = 62
# Capture FPS = 66
# Capture FPS = 50
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 35
# Capture FPS = 27
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 29
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 38
# Capture FPS = 52
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 47
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 37
# Capture FPS = 55
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 24
# Capture FPS = 50
# Capture FPS = 31
# Capture FPS = 37
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 37
# Capture FPS = 30
# Capture FPS = 37
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 37
# Capture FPS = 50
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 27
# Capture FPS = 33
# Capture FPS = 36
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 37
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 38
# Capture FPS = 31
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 27
# Capture FPS = 38
# Capture FPS = 55
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 45
# Capture FPS = 37
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 37
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 27
# Capture FPS = 36
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 27
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 50
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 27
# Capture FPS = 37
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 37
# Capture FPS = 29
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 31
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 45
# Capture FPS = 35
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 37
# Capture FPS = 28
# Capture FPS = 34
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 47
# Capture FPS = 36
# Capture FPS = 52
# Capture FPS = 35
# Capture FPS = 52
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 37
# Dataset size : 116500
# Capture FPS = 0
# Capture FPS = 35
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 36
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 29
# Capture FPS = 35
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 37
# Capture FPS = 33
# Capture FPS = 35
# Capture FPS = 62
# Capture FPS = 27
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 27
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 38
# Capture FPS = 52
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 55
# Capture FPS = 33
# Capture FPS = 26
# Capture FPS = 37
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 29
# Capture FPS = 37
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 30
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 28
# Capture FPS = 35
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 29
# Capture FPS = 27
# Capture FPS = 40
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 28
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 34
# Capture FPS = 30
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 58
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 30
# Capture FPS = 35
# Capture FPS = 30
# Capture FPS = 33
# Capture FPS = 34
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 29
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 34
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 33
# Capture FPS = 32
# Capture FPS = 31
# Capture FPS = 32
# Capture FPS = 30
# Capture FPS = 38
# Capture FPS = 62
# Capture FPS = 55
# Capture FPS = 57
# Capture FPS = 31
# Capture FPS = 31
# Capture FPS = 52
# Capture FPS = 33
# Capture FPS = 31
# Capture FPS = 30
# Capture FPS = 27
# Capture FPS = 23
# Capture FPS = 33
# Capture FPS = 62
# Capture FPS = 66
# Capture FPS = 55
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 58
# Capture FPS = 62
# Capture FPS = 55
# Capture FPS = 21
# Capture FPS = 37
# Capture FPS = 62
# Capture FPS = 66
# Capture FPS = 66
# Capture FPS = 58
# Capture FPS = 58
# Capture FPS = 66
# Capture FPS = 71
# Capture FPS = 66
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 58
# Capture FPS = 66
# Capture FPS = 66
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 58
# Capture FPS = 66
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 58
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 66
# Capture FPS = 62
# Capture FPS = 59
# Capture FPS = 55
# Capture FPS = 66
# Capture FPS = 62
# Capture FPS = 62
# Capture FPS = 58
# Capture FPS = 71
# Capture FPS = 66
# Capture FPS = 62
# Capture FPS = 52
# Capture FPS = 26
# Capture FPS = 30
# Capture FPS = 40
# Capture FPS = 30
# Capture FPS = 33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-8117f796c35e> in <module>
#      41 # in this main loop we do precessing
#      42 while(True):
# ---> 43     sct_image = sct.grab(monitor)
#      44     screen = np.array(sct_image)
#      45     screen = cv2.cvtColor(screen, cv2.COLOR_BGR2GRAY)   # We want the NN to play irrespective of colors
#
# ~\Anaconda3\envs\fastai\lib\site-packages\mss\windows.py in grab(self, monitor)
#     283             monitor["left"],
#     284             monitor["top"],
# --> 285             SRCCOPY | CAPTUREBLT,
#     286         )
#     287         bits = self.gdi32.GetDIBits(
#
# KeyboardInterrupt:

# %%
len(list(np.load(filename, allow_pickle=True)))
# Out:
# 116350
