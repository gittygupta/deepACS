# %%
from vision.ssd.vgg_ssd import create_vgg_ssd, create_vgg_ssd_predictor
from vision.ssd.mobilenetv1_ssd import create_mobilenetv1_ssd, create_mobilenetv1_ssd_predictor
from vision.ssd.mobilenetv1_ssd_lite import create_mobilenetv1_ssd_lite, create_mobilenetv1_ssd_lite_predictor
from vision.ssd.squeezenet_ssd_lite import create_squeezenet_ssd_lite, create_squeezenet_ssd_lite_predictor
from vision.ssd.mobilenet_v2_ssd_lite import create_mobilenetv2_ssd_lite, create_mobilenetv2_ssd_lite_predictor
from vision.utils.misc import Timer
from mss import mss
import cv2
import numpy as np
from PIL import ImageGrab
import time
import pyautogui
from numpy import ones,vstack
from numpy.linalg import lstsq
from statistics import mean
from directkeys import PressKey, ReleaseKey, W, A, S, D
import pyautogui

# %%
## Not to detect : 
## aeroplane
## bird
## boat
## cat
## chair
## diningtable
## pottedplant
## sheep
## sofa
## tvmonitor
## bottle
## motorbike

no_need = ['aeroplane', 'bird', 'boat', 'cat', 'chair', 'diningtable', 'pottedplant', 'sheep', 'sofa', 'tvmonitor', 'bottle', 'motorbike']

# %%
# utility functions
def straight():
    PressKey(W)
    ReleaseKey(A)
    ReleaseKey(D)

def left():
    PressKey(A)
    #ReleaseKey(W)#
    ReleaseKey(D)
    #ReleaseKey(A)   # Basically tapping the key 'A' once
    #ReleaseKey(W)

def right():
    PressKey(D)
    #ReleaseKey(W)#
    ReleaseKey(A)
    #ReleaseKey(D)   # Basically tapping the key 'A' once
    #ReleaseKey(W)

def stop():
    ReleaseKey(W)
    ReleaseKey(A)
    ReleaseKey(D)

def reposition1(count):
    while(count != 0):
        print(count)
        if count > 0:
            for i in range(5):
                straight()
            left()
            count -= 1
        elif count < 0:
            for i in range(5):
                straight()
            right()
            count += 1

# %%
net_type = r'mb1-ssd'
model_path = r'models/mobilenet-v1-ssd-mp-0_675.pth'
label_path = r'models/voc-model-labels.txt'

class_names = [name.strip() for name in open(label_path).readlines()]
num_classes = len(class_names)

net = create_mobilenetv1_ssd(len(class_names), is_test=True)
net.load(model_path)
predictor = create_mobilenetv1_ssd_predictor(net, candidate_size=200)

# %%
timer = Timer()

monitor = {'top' : 40, 'left' : 0, 'width' : 800, 'height' : 600}
sct = mss()

count = 0

# delay
for i in range(4):
    print(4 - i)
    time.sleep(1)
# kick
for i in range(10):
    time.sleep(0.3)
    straight()

while True:
    sct_image = sct.grab(monitor)
    orig_image = np.array(sct_image)
    if orig_image is None:
        continue

    image = cv2.cvtColor(orig_image, cv2.COLOR_BGR2RGB)
    timer.start()
    boxes, labels, probs = predictor.predict(image, 10, 0.4)
    #print("boxes : ", boxes)
    #print("labels : ", labels)
    #print("Probs : ", probs)
    interval = timer.end()
    #print('Time: {:.2f}s, Detect Objects: {:d}.'.format(interval, labels.size(0)))

    ## Game specific : Finding max probability of person, that'll be Jacob
    persons = []
    jacob = ['jacob', -1, [-1, -1, -1, -1]]   # characteristics of jacob
    for i in range(boxes.size(0)):
        box = boxes[i, :]
        label = class_names[labels[i]]
        if str(label) == 'person':
            persons.append(float(probs[i]))
    #print('persons : ', persons)
    if(len(persons) != 0):
        jacob[1] = max(persons)     # person with highest probability will be jacob
        jacob[2] = [box[0], box[1], box[2], box[3]]
    #print('Jacob' , jacob)
    ##

    for i in range(boxes.size(0)):
        box = boxes[i, :]
        label = f"{class_names[labels[i]]}: {probs[i]:.2f}"
        if float(probs[i]) == jacob[1]:
            label = f"{jacob[0]}: {probs[i]:.2f}"
        label1 = label.split(':')[0]

        ## Game specific : overlapping obstacles with jacob
        if label1 not in no_need:
            cv2.rectangle(orig_image, (box[0], box[1]), (box[2], box[3]), (255, 255, 0), 4)

            cv2.putText(orig_image, label,
                        (box[0]+20, box[1]+40),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        1,  # font scale
                        (255, 0, 255),
                        2)  # line type

            if str(label1) != 'jacob':
                if label1 == 'bicycle':     # cz in dark conditions jacob belt is detected as bicycle
                    if box[0] > (jacob[2][0] - 20) and box[0] < (jacob[2][0] + 20):
                        pass
                    elif box[2] > (jacob[2][2] - 20) and box[2] < (jacob[2][2] + 20):
                        pass
                elif (box[2] > (jacob[2][0])) and (box[2] < (jacob[2][2])):
                    right()
                    print('right')
                    count += 1
                elif (box[0] > (jacob[2][0])) and (box[0] < (jacob[2][2])):
                    left()
                    print('left')
                    count -= 1
                else:
                    straight()
                    print('straight')
         
        ##
        '''
        cv2.rectangle(orig_image, (box[0], box[1]), (box[2], box[3]), (255, 255, 0), 4)

        cv2.putText(orig_image, label,
                    (box[0]+20, box[1]+40),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,  # font scale
                    (255, 0, 255),
                    2)  # line type
        '''
    cv2.imshow('annotated', orig_image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# ference time:  0.03490710258483887
# straight
# Inference time:  0.03989267349243164
# straight
# Inference time: 0.03490567207336426
# Inference time:  0.038895368576049805
# Inference time:  0.03789973258972168
# straight
# Inference time:  0.037899017333984375
# straight
# Inference time:  0.03490567207336426
# straight
# Inference time:  0.044887542724609375
# Inference time: 0.0329134464263916
# Inference time:  0.025926589965820312
# straight
# Inference time:  0.02693319320678711
# Inference time:  0.025932788848876953
# Inference time:  0.03889608383178711
# Inference time: 0.030916690826416016
# Inference time:  0.0329129695892334
# Inference time:  0.038895606994628906
# Inference time:  0.03291177749633789
# Inference time: 0.03390908241271973
# Inference time:  0.036900997161865234
# Inference time:  0.03487062454223633
# Inference time:  0.0359039306640625
# Inference time: 0.03490781784057617
# Inference time:  0.033907175064086914
# Inference time: 0.03690075874328613
# Inference time:  0.029918193817138672
# Inference time: 0.0359034538269043
# Inference time:  0.030917882919311523
# Inference time: 0.030916452407836914
# Inference time:  0.030916452407836914
# Inference time:0.03092479705810547
# Inference time:  0.03291201591491699
# Inference time:  0.03690028190612793
# Inference time:  0.03291153907775879
# Inference time: 0.033910274505615234
# Inference time:  0.03391098976135254
# Inference time: 0.03391122817993164
# Inference time:  0.030917882919311523
# Inference time:  0.03490638732910156
# Inference time:  0.035903215408325195
# Inference time: 0.0359041690826416
# Inference time:  0.028922557830810547
# Inference time: 0.03191542625427246
# Inference time:  0.022938013076782227
# Inference time:  0.023937463760375977
# Inference time:  0.030982255935668945
# Inference time:  0.03796577453613281
# Inference time: 0.03738808631896973
# Inference time:  0.0359044075012207
# Inference time: 0.03690171241760254
# Inference time:  0.04617190361022949
# Inference time:  0.03690028190612793
# Inference time:  0.0468745231628418
# Inference time:  0.031914710998535156
# Inference time:  0.03842806816101074
# Inference time:  0.0329127311706543
# Inference time:  0.02891230583190918
# Inference time:  0.029918909072875977
# Inference time:  0.030917882919311523
# Inference time:  0.03690147399902344
# Inference time: 0.029918432235717773
# Inference time:  0.03390812873840332
# Inference time:  0.03390312194824219
# Inference time:  0.034914255142211914
# Inference time:  0.03590750694274902
# Inference time: 0.03590226173400879
# Inference time:  0.03391075134277344
# Inference time:  0.03590869903564453
# Inference time:  0.04288434982299805
# Inference time:  0.03290748596191406
# Inference time:  0.03391122817993164
# Inference time:  0.03590965270996094
# Inference time:  0.03890275955200195
# Inference time:  0.025929927825927734
# Inference time:  0.02292943000793457
# Inference time:  0.03091716766357422
# Inference time: 0.037894248962402344
# Inference time:  0.024932861328125
# Inference time:  0.030919790267944336
# Inference time:  0.030916213989257812
# Inference time:  0.04388737678527832
# Inference time: 0.034906864166259766
# Inference time:  0.030916690826416016
# straight
# Inference time:  0.04005932807922363
# straight
# Inference time:  0.03487253189086914
# straight
# Inference time:  0.036046743392944336
# straight
# Inference time:  0.030917644500732422
# straight
# Inference time:  0.037901878356933594
# straight
# Inference time:  0.04288458824157715
# right
# Inference time:  0.037903785705566406
# right
# Inference time: 0.032911062240600586
# right
# Inference time:  0.030434608459472656
# right
# Inference time:  0.035425424575805664
# right
# straight
# Inference time:  0.030916929244995117
# straight
# right
# Inference time:  0.025927066802978516
# straight
# straight
# Inference time:  0.026933670043945312
# right
# straight
# Inference time:  0.03989362716674805
# straight
# right
# Inference time:  0.040891170501708984
# straight
# right
# Inference time:  0.03989553451538086
# straight
# Inference time: 0.03191518783569336
# straight
# right
# Inference time:  0.032912254333496094
# right
# straight
# straight
# Inference time:  0.039896488189697266
# right
# straight
# Inference time:  0.034905433654785156
# straight
# straight
# Inference time: 0.03690171241760254
# straight
# right
# Inference time:  0.04288840293884277
# straight
# straight
# Inference time: 0.03390860557556152
# straight
# straight
# Inference time:  0.02892279624938965
# straight
# Inference time:  0.027924299240112305
# straight
# Inference time:  0.026927709579467773
# straight
# Inference time:  0.03091740608215332
# straight
# Inference time:  0.027927160263061523
# straight
# Inference time:  0.02891397476196289
# straight
# Inference time: 0.03702116012573242
# straight
# Inference time:  0.04696464538574219
# straight
# straight
# Inference time: 0.030058860778808594
# straight
# Inference time:  0.03618144989013672
# straight
# Inference time: 0.03390932083129883
# straight
# Inference time:  0.034267425537109375
# straight
# Inference time:  0.0329129695892334
# straight
# straight
# Inference time:  0.03479766845703125
# straight
# straight
# Inference time:  0.031919240951538086
# straight
# straight
# Inference time:  0.032912254333496094
# straight
# Inference time:  0.03291440010070801
# straight
# Inference time:  0.024930477142333984
# straight
# Inference time:  0.03490900993347168
# straight
# straight
# Inference time:  0.03191399574279785
# straight
# straight
# Inference time:  0.03191351890563965
# straight
# straight
# Inference time:  0.02792525291442871
# straight
# straight
# Inference time:  0.034906864166259766
# straight
# Inference time:  0.0359039306640625
# left
# Inference time:  0.03291177749633789
# straight
# Inference time:  0.03291177749633789
# straight
# Inference time:  0.03590583801269531
# straight
# straight
# Inference time:  0.03291177749633789
# straight
# Inference time: 0.032915353775024414
# straight
# Inference time:  0.029918909072875977
# straight
# Inference time:0.031915903091430664
# straight
# Inference time:  0.03391075134277344
# straight
# Inference time:  0.03889799118041992
# straight
# Inference time:  0.026927709579467773
# straight
# Inference time:  0.02991795539855957
# left
# straight
# Inference time:  0.03390765190124512
# left
# straight
# Inference time:  0.030919551849365234
# left
# Inference time:  0.03204631805419922
# left
# Inference time:  0.030994415283203125
# left
# Inference time:  0.04090619087219238
# left
# Inference time: 0.03390932083129883
# left
# Inference time:  0.03590798377990723
# left
# Inference time: 0.032910823822021484
# straight
# Inference time:  0.03490614891052246
# straight
# Inference time: 0.03889584541320801
# straight
# Inference time:  0.03740978240966797
# Inference time:  0.033425331115722656
# Inference time:  0.03690481185913086
# straight
# Inference time:  0.03291201591491699
# straight
# Inference time: 0.026926755905151367
# straight
# Inference time:  0.02991962432861328
# straight
# straight
# straight
# Inference time:  0.03590536117553711
# straight
# straight
# Inference time:  0.027924060821533203
# straight
# Inference time:  0.028923749923706055
# straight
# straight
# Inference time:  0.031913042068481445
# straight
# straight
# Inference time:  0.03889632225036621
# straight
# Inference time:  0.03191685676574707
# straight
# Inference time:  0.03590083122253418
# straight
# Inference time:  0.032883644104003906
# right
# straight
# Inference time:  0.03390693664550781
# straight
# Inference time:  0.0329132080078125
# straight
# Inference time:  0.03291058540344238
# straight
# Inference time:  0.0448756217956543
# straight
# Inference time: 0.03191399574279785
# straight
# Inference time:  0.033905029296875
# straight
# Inference time:  0.035906076431274414
# Inference time:  0.042404890060424805
# Inference time:  0.029915571212768555
# Inference time: 0.03889751434326172
# Inference time:  0.03191328048706055
# Inference time:  0.0359036922454834
# Inference time:  0.03490447998046875
# Inference time:  0.036900997161865234
# Inference time:  0.035906076431274414
# Inference time:  0.03989744186401367
# Inference time:  0.04487967491149902
# Inference time: 0.04587745666503906
# Inference time:  0.0448765754699707
# Inference time:  0.03789663314819336
# Inference time:  0.03390860557556152
# Inference time:  0.041887521743774414
# Inference time:  0.03790116310119629
# Inference time:  0.036897897720336914
# Inference time:  0.02792501449584961
# Inference time:  0.028925657272338867
# Inference time:  0.04293632507324219
# Inference time: 0.03191375732421875
# Inference time:  0.03485369682312012
# Inference time:  0.029924631118774414
# Inference time:  0.035903215408325195
# Inference time:  0.04188203811645508
# Inference time: 0.033908843994140625
# Inference time:  0.03212308883666992
# Inference time:  0.0388948917388916
# Inference time:  0.03390955924987793
# Inference time:  0.0468752384185791
# Inference time: 0.0359034538269043
# Inference time:  0.03889131546020508
# Inference time:  0.02792811393737793
# Inference time:  0.029920339584350586
# Inference time:  0.039887189865112305
# Inference time:  0.028920412063598633
# Inference time:  0.028922557830810547
# Inference time:  0.04188895225524902
# Inference time:  0.032912254333496094
# Inference time:  0.032915353775024414
# Inference time:  0.03689980506896973
# Inference time:  0.033911705017089844
# Inference time:  0.04288482666015625
# Inference time:  0.034906625747680664
# Inference time: 0.03990316390991211
# Inference time:  0.03490638732910156
# Inference time:  0.03789925575256348
# Inference time:  0.03490757942199707
# Inference time:  0.039414405822753906
# straight
# Inference time:  0.034906625747680664
# Inference time:  0.03889107704162598
# Inference time:  0.0329134464263916
# Inference time:  0.0299222469329834
# Inference time:  0.0329127311706543
# Inference time:  0.03661465644836426
# Inference time:  0.02991652488708496
# Inference time:  0.027926206588745117
# Inference time:  0.04160761833190918
# Inference time:  0.03291058540344238
# Inference time:  0.03590512275695801
# Inference time:  0.043890953063964844
# Inference time: 0.032913923263549805
# Inference time:  0.03690290451049805
# Inference time:  0.03390955924987793
# straight
# Inference time:  0.033420562744140625
# straight
# straight
# Inference time:  0.03441739082336426
# straight
# Inference time:  0.029920578002929688
# straight
# Inference time:  0.035904884338378906
# straight
# Inference time:  0.024927854537963867
# Inference time:  0.03291010856628418
# right
# straight
# Inference time:  0.030916690826416016
# right
# straight
# Inference time:  0.028921842575073242
# right
# straight
# Inference time:  0.031914710998535156
# straight
# straight
# Inference time:  0.04587602615356445
# straight
# straight
# Inference time:  0.02991962432861328
# straight
# Inference time:  0.03690028190612793
# Inference time:  0.04388427734375
# Inference time:  0.03390812873840332
# Inference time:  0.03291010856628418
# Inference time:  0.038890838623046875
# Inference time:  0.03291201591491699
# Inference time:  0.03889822959899902
# Inference time:  0.032915353775024414
# Inference time:  0.029920101165771484
# Inference time:  0.043883323669433594
# Inference time: 0.03091740608215332
# Inference time:  0.03396201133728027
# Inference time:  0.025998592376708984
# Inference time:  0.02801370620727539
# Inference time:  0.03407144546508789
# Inference time:  0.031972646713256836
# Inference time:  0.029918432235717773
# Inference time:  0.03490638732910156
# Inference time: 0.04089021682739258
# Inference time:  0.034906625747680664
# Inference time:  0.03941798210144043
# Inference time:  0.03541874885559082
# Inference time:  0.04189348220825195
# Inference time: 0.03989577293395996
# Inference time:  0.04288506507873535
# Inference time: 0.03590583801269531
# Inference time:  0.03490948677062988
# Inference time: 0.029924631118774414
# Inference time:  0.033011436462402344
# straight
# Inference time:  0.027051687240600586
# Inference time:  0.036055564880371094
# Inference time:  0.03299307823181152
# Inference time:  0.02892160415649414
# Inference time:  0.030483722686767578
# Inference time:  0.04006481170654297
# Inference time:  0.03490710258483887
# straight
# Inference time:  0.041947126388549805
# Inference time: 0.04001641273498535
# Inference time:  0.03402876853942871
# Inference time: 0.03689146041870117
# Inference time:  0.03396773338317871
# Inference time:  0.036008358001708984
# Inference time:  0.03003549575805664
# straight
# Inference time:  0.046881675720214844
# straight
# Inference time: 0.03323006629943848
# straight
# straight
# Inference time:  0.0359041690826416
# straight
# Inference time:  0.025929689407348633
# straight
# Inference time:  0.029920339584350586
# straight
# Inference time:  0.033914804458618164
# straight
# Inference time:  0.03390336036682129
# straight
# Inference time:  0.02998661994934082
# left
# straight
# Inference time:  0.03490614891052246
# left
# straight
# Inference time:  0.03390645980834961
# straight
# Inference time:  0.03490471839904785
# straight
# Inference time:  0.03191256523132324
# straight
# Inference time: 0.03889656066894531
# straight
# Inference time:  0.036031246185302734
# left
# straight
# Inference time: 0.03390908241271973
# left
# straight
# Inference time:  0.030973196029663086
# left
# straight
# Inference time:  0.03359270095825195
# left
# straight
# Inference time:  0.029918193817138672
# straight
# Inference time:  0.038895368576049805
# straight
# Inference time:  0.026927709579467773
# straight
# straight
# Inference time:  0.04587984085083008
# straight
# Inference time: 0.027922868728637695
# straight
# Inference time:  0.03590512275695801
# left
# straight
# Inference time: 0.028865814208984375
# left
# straight
# Inference time:  0.030918598175048828
# left
# straight
# Inference time: 0.03690075874328613
# straight
# straight
# Inference time:  0.039891958236694336
# straight
# Inference time: 0.035909414291381836
# straight
# Inference time:  0.034906625747680664
# straight
# Inference time: 0.03390955924987793
# straight
# Inference time:  0.03690910339355469
# straight
# Inference time: 0.03191637992858887
# Inference time:  0.03291058540344238
# Inference time:  0.02892327308654785
# Inference time:  0.03202390670776367
# Inference time:  0.03401303291320801
# Inference time:  0.024933338165283203
# Inference time:  0.02892303466796875
# Inference time:  0.04306530952453613
# Inference time: 0.04196763038635254
# Inference time:  0.03191351890563965
# Inference time:  0.033865928649902344
# Inference time:  0.03490614891052246
# Inference time:  0.040076255798339844
# Inference time:  0.03804516792297363
# Inference time:  0.03391122817993164
# Inference time:  0.04700016975402832
# Inference time:0.0351870059967041
# Inference time:  0.035901784896850586
# Inference time:  0.03690624237060547
# Inference time:  0.031986236572265625
# Inference time:  0.03411984443664551
# Inference time:  0.02892327308654785
# Inference time:  0.025933027267456055
# Inference time:  0.03592324256896973
# Inference time:  0.03208470344543457
# Inference time:  0.0349273681640625
# Inference time:  0.044879913330078125
# Inference time: 0.03286480903625488
# Inference time:  0.03679227828979492
# Inference time: 0.03690052032470703
# Inference time:  0.03590202331542969
# Inference time:  0.03490710258483887
# Inference time:  0.03988838195800781
# Inference time:  0.042920589447021484
# Inference time: 0.03590273857116699
# Inference time:  0.03390908241271973
# Inference time:  0.028924226760864258
# Inference time:  0.03391242027282715
# Inference time:  0.036902427673339844
# Inference time:  0.036901235580444336
# Inference time:  0.029918670654296875
# Inference time:  0.03690052032470703
# Inference time:  0.03391146659851074
# Inference time:  0.03391098976135254
# Inference time:  0.03490781784057617
# Inference time:  0.029919147491455078
# Inference time:  0.04188179969787598
# Inference time:  0.05285906791687012
# Inference time: 0.03940916061401367
# Inference time:  0.0349125862121582
# Inference time:  0.035802364349365234
# Inference time:  0.033910274505615234
# Inference time:  0.04089641571044922
# Inference time:  0.030462265014648438
# Inference time:  0.03941679000854492
# Inference time:  0.041893720626831055
# Inference time:  0.0301513671875
# Inference time:  0.02804851531982422
# Inference time:  0.03427624702453613
# Inference time: 0.03989553451538086
# Inference time:  0.02991962432861328
# Inference time:  0.03191781044006348
# Inference time:  0.03191328048706055
# Inference time:  0.03392934799194336
# Inference time:  0.03690052032470703
# Inference time:  0.027925491333007812
# Inference time:  0.03490614891052246
# straight
# Inference time:  0.031914472579956055
# straight
# Inference time:  0.0458836555480957
# straight
# Inference time:  0.04639887809753418
# Inference time: 0.04188990592956543
# Inference time:  0.0359041690826416
# Inference time:  0.03590059280395508
# Inference time:  0.029918909072875977
# Inference time:  0.040886878967285156
# Inference time:  0.027925968170166016
# Inference time:  0.030916690826416016
# Inference time:  0.04487752914428711
# Inference time: 0.03790020942687988
# Inference time:  0.030917644500732422
# Inference time:  0.03690290451049805
# Inference time:  0.03889751434326172
# Inference time:  0.03989553451538086
# Inference time:  0.039891958236694336
# Inference time:  0.03291177749633789
# Inference time:  0.04488062858581543
# Inference time:  0.03490900993347168
# Inference time:  0.03690290451049805
# Inference time:  0.034905433654785156
# Inference time:  0.032912492752075195
# Inference time:  0.03390860557556152
# Inference time:  0.035797834396362305
# Inference time:  0.03091716766357422
# Inference time:  0.026926755905151367
# Inference time:  0.03191399574279785
# Inference time:  0.0329132080078125
# Inference time:  0.031914472579956055
# Inference time:  0.038899898529052734
# Inference time:  0.03326749801635742
# Inference time:  0.0339055061340332
# Inference time:  0.04587602615356445
# Inference time:  0.03191518783569336
# Inference time:  0.03889942169189453
# Inference time:  0.04288125038146973
# Inference time: 0.03889584541320801
# Inference time:  0.03790092468261719
# Inference time:  0.03490638732910156
# Inference time:  0.02991199493408203
# Inference time:  0.03690171241760254
# Inference time:  0.026927471160888672
# Inference time:  0.02991962432861328
# Inference time:  0.039904117584228516
# Inference time:  0.030917644500732422
# Inference time:  0.03490877151489258
# Inference time:  0.04587554931640625
# Inference time: 0.03490734100341797
# Inference time:  0.03890538215637207
# Inference time: 0.03789091110229492
# Inference time:  0.036905765533447266
# Inference time:  0.03390789031982422
# Inference time:  0.03789973258972168
# Inference time:  0.04488015174865723
# Inference time: 0.03490638732910156
# Inference time:  0.03291130065917969
# Inference time:  0.037893056869506836
# Inference time:  0.02792525291442871
# Inference time:  0.03390860557556152
# Inference time:  0.030917882919311523
# Inference time:  0.026929140090942383
# Inference time:  0.03690052032470703
# Inference time:  0.03390908241271973
# Inference time:  0.03590726852416992
# Inference time:  0.035904884338378906
# Inference time:  0.02991962432861328
# Inference time:  0.042887210845947266
# Inference time:  0.04089236259460449
# Inference time:  0.03590202331542969
# Inference time:  0.030917644500732422
# Inference time:  0.03690052032470703
# Inference time:  0.03490757942199707
# Inference time:  0.034906864166259766
# Inference time:  0.0359041690826416
# Inference time:  0.030916929244995117
# Inference time:  0.028923749923706055
# Inference time:  0.03291177749633789
# Inference time:  0.030916690826416016
# Inference time:  0.02892303466796875
# Inference time:  0.03889656066894531
# Inference time:  0.03390765190124512
# Inference time:  0.03490781784057617
# Inference time:  0.034905195236206055
# Inference time:  0.02991938591003418
# Inference time:  0.03391122817993164
# Inference time:  0.04687380790710449
# Inference time:  0.037897348403930664
# Inference time:  0.031914472579956055
# Inference time:  0.03490614891052246
# Inference time:  0.039891719818115234
# Inference time:  0.04587721824645996
# Inference time:  0.030914783477783203
# Inference time:  0.016954660415649414
# Inference time:  0.03395223617553711
# Inference time:  0.026128053665161133
# Inference time:  0.03191542625427246
# Inference time:  0.03690075874328613
# Inference time:  0.037901878356933594
# Inference time:  0.03889966011047363
# Inference time:  0.030432939529418945
# Inference time:  0.019945859909057617
# straight
# Inference time:  0.019942283630371094
# straight
# Inference time:  0.028922319412231445
# straight
# Inference time:  0.029919862747192383
# straight
# Inference time:  0.0368952751159668
# straight
# Inference time:  0.022944927215576172
# straight
